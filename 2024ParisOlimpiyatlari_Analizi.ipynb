# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Date, Opponent, Player, Points, Attack, Block, Serve
data = [["29-07-2024","Netherlands","Melissa Vargas",30,29,1,0,"Opposite Spiker"],
    ["01-08-2024","Dominican Republic","Melissa Vargas",31,26,2,3,"Opposite Spiker"],
    ["04-08-2024","Italy","Melissa Vargas",13,13,0,0,"Opposite Spiker"],
    ["06-08-2024","China","Melissa Vargas",42,38,2,2,"Opposite Spiker"],
    ["08-08-2024","Italy","Melissa Vargas",17,17,0,0,"Opposite Spiker"],
    ["10-08-2024","Brazil","Melissa Vargas",17,17,0,0,"Opposite Spiker"],
    
    ["29-07-2024","Netherlands","Ebrar Karakurt",10,9,1,0,"Outside Hitter"],
    ["01-08-2024","Dominican Republic","Ebrar Karakurt",3,2,0,1,"Outside Hitter"],
    ["04-08-2024","Italy","Ebrar Karakurt",1,1,0,0,"Outside Hitter"],
    ["06-08-2024","China","Ebrar Karakurt",7,5,0,2,"Outside Hitter"],
    ["08-08-2024","Italy","Ebrar Karakurt",3,3,0,0,"Outside Hitter"],
    ["10-08-2024","Brazil","Ebrar Karakurt",0,0,0,0,"Outside Hitter"],
    
    ["29-07-2024","Netherlands","Eda Erdem Dündar",12,9,2,1,"Middle Blocker"],
    ["01-08-2024","Dominican Republic","Eda Erdem Dündar",14,11,2,1,"Middle Blocker"],
    ["04-08-2024","Italy","Eda Erdem Dündar",3,3,0,0,"Middle Blocker"],
    ["06-08-2024","China","Eda Erdem Dündar",9,8,1,0,"Middle Blocker"],
    ["08-08-2024","Italy","Eda Erdem Dündar",7,5,2,0,"Middle Blocker"],
    ["10-08-2024","Brazil","Eda Erdem Dündar",13,6,7,0,"Middle Blocker"],
    
    ["29-07-2024","Netherlands","Derya Cebecioğlu",3,3,0,0,"Outside Hitter"],
    ["01-08-2024","Dominican Republic","Derya Cebecioğlu",0,0,0,0,"Outside Hitter"],
    ["04-08-2024","Italy","Derya Cebecioğlu",4,4,0,0,"Outside Hitter"],
    ["06-08-2024","China","Derya Cebecioğlu",5,3,1,1,"Outside Hitter"],
    ["08-08-2024","Italy","Derya Cebecioğlu",7,7,0,0,"Outside Hitter"],
    ["10-08-2024","Brazil","Derya Cebecioğlu",14,12,0,2,"Outside Hitter"],
    
    ["29-07-2024","Netherlands","Meliha Diken",3,3,0,0,"Outside Hitter"],
    ["01-08-2024","Dominican Republic","Meliha Diken",0,0,0,0,"Outside Hitter"],
    ["04-08-2024","Italy","Meliha Diken",0,0,0,0,"Outside Hitter"],
    ["06-08-2024","China","Meliha Diken",8,6,1,1,"Outside Hitter"],
    ["08-08-2024","Italy","Meliha Diken",4,4,0,0,"Outside Hitter"],
    ["10-08-2024","Brazil","Meliha Diken",6,4,2,0,"Outside Hitter"],
    
    ["29-07-2024","Netherlands","Aslı Kalaç",7,4,2,1,"Middle Blocker"],
    ["01-08-2024","Dominican Republic","Aslı Kalaç",0,0,0,0,"Middle Blocker"],
    ["04-08-2024","Italy","Aslı Kalaç",0,0,0,0,"Middle Blocker"],
    ["06-08-2024","China","Aslı Kalaç",0,0,0,0,"Middle Blocker"],
    ["08-08-2024","Italy","Aslı Kalaç",0,0,0,0,"Middle Blocker"],
    ["10-08-2024","Brazil","Aslı Kalaç",6,2,3,1,"Middle Blocker"],
    
    ["29-07-2024","Netherlands","Elif Şahin",3,1,1,1,"Setter"],
    ["01-08-2024","Dominican Republic","Elif Şahin",3,1,0,2,"Setter"],
    ["04-08-2024","Italy","Elif Şahin",1,1,0,0,"Setter"],
    ["06-08-2024","China","Elif Şahin",4,4,0,0,"Setter"],
    ["08-08-2024","Italy","Elif Şahin",4,2,2,0,"Setter"],
    ["10-08-2024","Brazil","Elif Şahin",3,1,2,0,"Setter"],
    
    ["29-07-2024","Netherlands","Hande Baladın",12,10,1,1,"Outside Hitter"],
    ["01-08-2024","Dominican Republic","Hande Baladın",10,5,3,2,"Outside Hitter"],
    ["04-08-2024","Italy","Hande Baladın",6,6,0,0,"Outside Hitter"],
    ["06-08-2024","China","Hande Baladın",13,11,1,1,"Outside Hitter"],
    ["08-08-2024","Italy","Hande Baladın",4,4,0,0,"Outside Hitter"],
    ["10-08-2024","Brazil","Hande Baladın",1,1,0,0,"Outside Hitter"],
    
    ["29-07-2024","Netherlands","Gizem Örge",0,0,0,0,"Libero"],
    ["01-08-2024","Dominican Republic","Gizem Örge",0,0,0,0,"Libero"],
    ["04-08-2024","Italy","Gizem Örge",0,0,0,0,"Libero"],
    ["06-08-2024","China","Gizem Örge",0,0,0,0,"Libero"],
    ["08-08-2024","Italy","Gizem Örge",0,0,0,0,"Libero"],
    ["10-08-2024","Brazil","Gizem Örge",0,0,0,0,"Libero"],
    
    ["29-07-2024","Netherlands","Cansu Özbay",0,0,0,0,"Setter"],
    ["01-08-2024","Dominican Republic","Cansu Özbay",0,0,0,0,"Setter"],
    ["04-08-2024","Italy","Cansu Özbay",1,0,1,0,"Setter"],
    ["06-08-2024","China","Cansu Özbay",0,0,0,0,"Setter"],
    ["08-08-2024","Italy","Cansu Özbay",0,0,0,0,"Setter"],
    ["10-08-2024","Brazil","Cansu Özbay",0,0,0,0,"Setter"],
    
    ["01-08-2024","Dominican Republic","Zehra Güneş",9,5,4,0,"Middle Blocker"],
    ["04-08-2024","Italy","Zehra Güneş",4,2,1,1,"Middle Blocker"],
    ["06-08-2024","China","Zehra Güneş",7,3,2,2,"Middle Blocker"],
    ["08-08-2024","Italy","Zehra Güneş",6,2,4,0,"Middle Blocker"],
    ["10-08-2024","Brazil","Cansu Özbay",0,0,0,0,"Middle Blocker"],
    
    ["29-07-2024","Netherlands","İlkin Aydın",0,0,0,0,"Outside Hitter"],
    ["01-08-2024","Dominican Republic","İlkin Aydın",10,10,0,0,"Outside Hitter"],
    ["04-08-2024","Italy","İlkin Aydın",2,2,0,0,"Outside Hitter"],
    ["06-08-2024","China","İlkin Aydın",0,0,0,0,"Outside Hitter"],
    ["08-08-2024","Italy","İlkin Aydın",0,0,0,0,"Outside Hitter"],
    ["10-08-2024","Brazil","İlkin Aydın",0,0,0,0,"Outside Hitter"]]

columns_volleyboll = ["Date", "Opponent", "Player", "Points", "Attack Points", "Block Points", "Serve Points","Position"]
df_volleyboll = pd.DataFrame(data, columns = columns_volleyboll)
df_volleyboll.to_csv("turkeyvolleyboll_2024parisolympics_2024.csv", index=False, encoding="utf-8-sig")

# %%
df_volleyboll
# Out:
#           Date            Opponent          Player  Points  Attack Points  \
# 0   29-07-2024         Netherlands  Melissa Vargas      30             29
# 1   01-08-2024  Dominican Republic  Melissa Vargas      31             26
# 2   04-08-2024               Italy  Melissa Vargas      13             13
# 3   06-08-2024               China  Melissa Vargas      42             38
# 4   08-08-2024               Italy  Melissa Vargas      17             17
# ..         ...                 ...             ...     ...            ...
# 66  01-08-2024  Dominican Republic     İlkin Aydın      10             10
# 67  04-08-2024               Italy     İlkin Aydın       2              2
# 68  06-08-2024               China     İlkin Aydın       0              0
# 69  08-08-2024               Italy     İlkin Aydın       0              0
# 70  10-08-2024              Brazil     İlkin Aydın       0              0
#
#     Block Points  Serve Points         Position
# ...

# %%
df_volleyboll.head()
# Out:
#          Date            Opponent          Player  Points  Attack Points  \
# 0  29-07-2024         Netherlands  Melissa Vargas      30             29
# 1  01-08-2024  Dominican Republic  Melissa Vargas      31             26
# 2  04-08-2024               Italy  Melissa Vargas      13             13
# 3  06-08-2024               China  Melissa Vargas      42             38
# 4  08-08-2024               Italy  Melissa Vargas      17             17
#
#    Block Points  Serve Points         Position
# 0             1             0  Opposite Spiker
# 1             2             3  Opposite Spiker
# 2             0             0  Opposite Spiker
# 3             2             2  Opposite Spiker
# 4             0             0  Opposite Spiker

# %%
df_volleyboll.tail()
# Out:
#           Date            Opponent       Player  Points  Attack Points  \
# 66  01-08-2024  Dominican Republic  İlkin Aydın      10             10
# 67  04-08-2024               Italy  İlkin Aydın       2              2
# 68  06-08-2024               China  İlkin Aydın       0              0
# 69  08-08-2024               Italy  İlkin Aydın       0              0
# 70  10-08-2024              Brazil  İlkin Aydın       0              0
#
#     Block Points  Serve Points        Position
# 66             0             0  Outside Hitter
# 67             0             0  Outside Hitter
# 68             0             0  Outside Hitter
# 69             0             0  Outside Hitter
# 70             0             0  Outside Hitter

# %%
player_totals = df_volleyboll.groupby("Player")[["Points","Attack Points","Block Points","Serve Points"]].sum()

# %%
player_totals.sort_values(["Points","Attack Points","Block Points","Serve Points"],ascending=False)
# Out:
#                   Points  Attack Points  Block Points  Serve Points
# Player
# Melissa Vargas       150            140             5             5
# Eda Erdem Dündar      58             42            14             2
# Hande Baladın         46             37             5             4
# Derya Cebecioğlu      33             29             1             3
# Zehra Güneş           26             12            11             3
# Ebrar Karakurt        24             20             1             3
# Meliha Diken          21             17             3             1
# Elif Şahin            18             10             5             3
# Aslı Kalaç            13              6             5             2
# İlkin Aydın           12             12             0             0
# Cansu Özbay            1              0             1             0
# Gizem Örge             0              0             0             0

# %%
# Sadece sayısal sütunları al
heatmap_data = player_totals[["Points","Attack Points","Block Points","Serve Points"]]
plt.figure(figsize=(10,6), dpi=200)
sns.heatmap(
    heatmap_data, 
    annot=True,        # hücre değerlerini göster      
    fmt=".0f", # tam sayı formatı
    cmap="YlGnBu",     # sarı-yeşil-mavi tonları
    cbar_kws={'label': 'Puan'}  # renk çubuğu etiketi
)

plt.title("Paris 2024: Oyuncu Toplam Puanları ve Alt Kategoriler", fontsize=14)
plt.ylabel("Oyuncular")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
y = df_volleyboll.groupby("Player")["Points"].sum()
plt.figure(figsize=(10,6),dpi=200)
y.plot(kind="barh",color="#d60000",label="Toplam puan",)

plt.title("Paris 2024: Filenin Sultanları – Oyuncu Bazlı Toplam Puanlar")
plt.xlabel("Toplam Puan",fontsize=12)
plt.ylabel("Oyuncular",fontsize=12)
plt.grid(alpha=0.2)
plt.tight_layout()
plt.legend()
plt.show()

# %%
# outside hitterları kendi aralarında değerlendirelim.
outside_hitters = df_volleyboll[df_volleyboll["Position"] == "Outside Hitter"]
outside_totals = outside_hitters.groupby("Player")[["Attack Points","Serve Points"]].sum()
plt.figure(dpi=200)
outside_totals.plot(
    kind="barh",
    stacked=False,   # attack ve serve ayrı ayrı görünsün
    figsize=(10,6),
    color=["#4900B0","#FF8000"]  
)

plt.xlabel("Toplam Puan",fontsize=12)
plt.ylabel("Outside Hitter Oyuncular",fontsize=12)
plt.title("Paris 2024: Outside Hitter Performansları")
plt.grid(alpha=0.2)
plt.legend()
plt.tight_layout()
plt.show()

# %%
# middle blocker için kendi aralarında değerlendirelim.
outside_hitters = df_volleyboll[df_volleyboll["Position"] == "Middle Blocker"]
outside_totals = outside_hitters.groupby("Player")[["Block Points","Attack Points"]].sum()
plt.figure(dpi=200)
outside_totals.plot(
    kind="barh",
    stacked=False,   # attack ve block ayrı ayrı görünsün
    figsize=(10,6),
    color=["#8E44AD","#16A085"]  
)

plt.xlabel("Toplam Puan",fontsize=12)
plt.ylabel("Middle Blocker Oyuncular",fontsize=12)
plt.title("Paris 2024: Middle Blocker Performansları")
plt.grid(alpha=0.2)
plt.legend()
plt.tight_layout()
plt.show()
